# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../dataset/data.csv')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 4515  9274-UARKJ  Female              0      No         No      15
# 6405  5298-GSTLM  Female              1      No         No      60
# 3547  1568-BEKZM    Male              1     Yes         No      70
# 6533  1104-TNLZA    Male              1     Yes         No      28
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 6993          Yes           Yes     Fiber optic             No  ...
# 4515          Yes            No     Fiber optic             No  ...
# 6405          Yes           Yes     Fiber optic            Yes  ...
# 3547          Yes           Yes             DSL            Yes  ...
# 6533          Yes           Yes     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 6993               No          No         Yes              No  Month-to-month
# 4515               No          No         Yes              No  Month-to-month
# 6405               No          No         Yes             Yes        One year
# 3547              Yes         Yes         Yes             Yes        Two year
# 6533               No         Yes         Yes             Yes  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 6993              Yes           Electronic check          88.05       4367.35
# 4515              Yes  Bank transfer (automatic)          83.20          1130
# 6405              Yes  Bank transfer (automatic)         101.40        6176.6
# 3547               No    Credit card (automatic)          90.05        6333.4
# 6533              Yes           Electronic check         105.80          2998
#
#      Churn
# 6993   Yes
# 4515    No
# 6405    No
# 3547    No
# 6533    No
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Shape of Data : (7043, 21) ###
# ### Target Variable : Churn ###
# ### Objective : To predict whether a customer will churn or not based on the given features. ###

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize = True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64
